# %%
import matplotlib.pyplot as plt

# %%
x = [1.25, 1.50, 1.75, 2.0]

plt.rcParams.update(
    {
        "font.size": 18,
        "axes.labelsize": 20,
        "axes.titlesize": 20,
        "legend.fontsize": 18,
        "xtick.labelsize": 18,
        "ytick.labelsize": 18,
        "figure.figsize": (7, 5),
        "lines.linewidth": 2.2,
    }
)

# %% [markdown]
# # P = 2

# %%
# psed_vanilla
psed_vanilla_s = [12.446736574172974, 118.97893047332764, 412.59264969825745, 745.3477964401245] # *!
psed_vanilla_iter = [30741150, 274334823, 914233016, 1565817691] # *!

# psed_parallel_bsf
psed_parallel_bsf_s = [0.807180643081665, 2.232726573944092, 4.471726894378662, 8.108012914657593]
psed_parallel_bsf_iter = [4141267, 29345242, 85806480, 149748703]

# psed_parallel_bsf_lb
psed_parallel_bsf_lb_s = [3.6604297161102295, 4.679238796234131, 9.083287954330444, 13.540831327438354]
psed_parallel_bsf_lb_iter = [4114658, 27620890, 82350548, 143525172]

# psdtw_vanilla
psdtw_vanilla_s = [419.21485781669617, 4559.293148994446, 15245.766177892685, 30396.453424215317] # *!
psdtw_vanilla_iter = [32540659, 274994784, 880764560, 1513184734] # *!

# psdtw_parallel_bsf
psdtw_parallel_bsf_s = [12.747251749038696, 54.902995347976685, 119.584951877594, 211.94983291625977]
psdtw_parallel_bsf_iter = [5896910, 39041856, 102398510, 172636605]

# psdtw_parallel_bsf_lb
psdtw_parallel_bsf_lb_s = [12.809888362884521, 52.313098669052124, 110.09110879898071, 194.55042958259583]
psdtw_parallel_bsf_lb_iter = [5450858, 35040848, 91372708, 151836186]

# %%
for i in range(4):
    time_for_lb_psed = psed_parallel_bsf_lb_s[i] - (psed_parallel_bsf_s[i] / psed_parallel_bsf_iter[i]) * psed_parallel_bsf_lb_iter[i]
    print(
        f"Time for LB (PSED): {time_for_lb_psed:.3f} "
        f"Time proportion for LB (PSED): {time_for_lb_psed/psed_parallel_bsf_lb_s[i]:.3f} "
    )
print("\n")
for i in range(4):
    time_for_lb_psdtw = psdtw_parallel_bsf_lb_s[i] - (psdtw_parallel_bsf_s[i] / psdtw_parallel_bsf_iter[i]) * psdtw_parallel_bsf_lb_iter[i]
    print(
        f"Time for LB (PSDTW): {time_for_lb_psdtw:.3f} "
        f"Time proportion for LB (PSDTW): {time_for_lb_psdtw/psdtw_parallel_bsf_lb_s[i]:.3f} "
    )
# Out:
# Time for LB (PSED): 2.858 Time proportion for LB (PSED): 0.781
# Time for LB (PSED): 2.578 Time proportion for LB (PSED): 0.551
# Time for LB (PSED): 4.792 Time proportion for LB (PSED): 0.528
# Time for LB (PSED): 5.770 Time proportion for LB (PSED): 0.426
#
#
# Time for LB (PSDTW): 1.027 Time proportion for LB (PSDTW): 0.080
# Time for LB (PSDTW): 3.037 Time proportion for LB (PSDTW): 0.058
# Time for LB (PSDTW): 3.383 Time proportion for LB (PSDTW): 0.031
# Time for LB (PSDTW): 8.138 Time proportion for LB (PSDTW): 0.042

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_vanilla_s, color=c_vanilla, marker="o", linestyle="-", label=r"PSED_vanilla")
ax.plot(x, psed_parallel_bsf_s, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_vanilla_s, color=c_vanilla, marker="o", linestyle="--", label=r"PSDTW_vanilla")
ax.plot(x, psdtw_parallel_bsf_s, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("Runtime (s)")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
# plt.savefig("../figures/gunpoint-runtime-P2-time.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_parallel_bsf_s, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_parallel_bsf_s, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("Runtime (s)")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
# plt.savefig("../figures/gunpoint-runtime-P2-focus-time.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_vanilla_iter, color=c_vanilla, marker="o", linestyle="-", label=r"PSED_vanilla")
ax.plot(x, psed_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_vanilla_iter, color=c_vanilla, marker="o", linestyle="--", label=r"PSDTW_vanilla")
ax.plot(x, psdtw_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("# Distance Calls")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
# plt.savefig("../figures/gunpoint-runtime-P2-distance-call.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("# Distance Calls")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
# plt.savefig("../figures/gunpoint-runtime-P2-focus-distance-call.pdf", format="pdf", bbox_inches="tight")

plt.show()

# %% [markdown]
# # P = 3

# %%
# psed_vanilla
psed_vanilla_s = [18.394218921661377, 215.26686477661133, 700.9349184036255, 1529.5894598960876] # *!
psed_vanilla_iter = [60658171, 659109745, 2119408092, 4200540991] # *!

# psed_parallel_bsf
psed_parallel_bsf_s = [0.8988838195800781, 3.293431520462036, 7.391644239425659, 10.613930940628052]
psed_parallel_bsf_iter = [7399224, 69752469, 207756992, 377012300]

# psed_parallel_bsf_lb
psed_parallel_bsf_lb_s = [2.2021493911743164, 4.736392259597778, 9.17707085609436, 16.10451030731201]
psed_parallel_bsf_lb_iter = [6776486, 61558080, 183604705, 326062538]

# psdtw_vanilla
psdtw_vanilla_s = [341.6239402294159, 5044.003716945648, 16391.769976854324, 37835.05887246132] # *!
psdtw_vanilla_iter = [63268968, 664255610, 2056565223, 4054178881] # *!

# psdtw_parallel_bsf
psdtw_parallel_bsf_s = [12.327959060668945, 66.50206851959229, 142.76466870307922, 269.66712474823]
psdtw_parallel_bsf_iter = [11526131, 101355615, 261383600, 505973576]

# psdtw_parallel_bsf_lb
psdtw_parallel_bsf_lb_s = [11.99645709991455, 59.943809270858765, 121.27489352226257, 225.47284269332886]
psdtw_parallel_bsf_lb_iter = [10059055, 85931659, 216663934, 405889088]

# Speedup: 1.03x	1.11x	1.18x	1.20x

# %%
for i in range(4):
    time_for_lb_psed = psed_parallel_bsf_lb_s[i] - (psed_parallel_bsf_s[i] / psed_parallel_bsf_iter[i]) * psed_parallel_bsf_lb_iter[i]
    print(
        f"Time for LB (PSED): {time_for_lb_psed:.3f} "
        f"Time proportion for LB (PSED): {time_for_lb_psed/psed_parallel_bsf_lb_s[i]:.3f} "
    )
print("\n")
for i in range(4):
    time_for_lb_psdtw = psdtw_parallel_bsf_lb_s[i] - (psdtw_parallel_bsf_s[i] / psdtw_parallel_bsf_iter[i]) * psdtw_parallel_bsf_lb_iter[i]
    print(
        f"Time for LB (PSDTW): {time_for_lb_psdtw:.3f} "
        f"Time proportion for LB (PSDTW): {time_for_lb_psdtw/psdtw_parallel_bsf_lb_s[i]:.3f} "
    )
# Out:
# Time for LB (PSED): 1.379 Time proportion for LB (PSED): 0.626
# Time for LB (PSED): 1.830 Time proportion for LB (PSED): 0.386
# Time for LB (PSED): 2.645 Time proportion for LB (PSED): 0.288
# Time for LB (PSED): 6.925 Time proportion for LB (PSED): 0.430
#
#
# Time for LB (PSDTW): 1.238 Time proportion for LB (PSDTW): 0.103
# Time for LB (PSDTW): 3.562 Time proportion for LB (PSDTW): 0.059
# Time for LB (PSDTW): 2.936 Time proportion for LB (PSDTW): 0.024
# Time for LB (PSDTW): 9.147 Time proportion for LB (PSDTW): 0.041

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_vanilla_s, color=c_vanilla, marker="o", linestyle="-", label=r"PSED_vanilla")
ax.plot(x, psed_parallel_bsf_s, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_vanilla_s, color=c_vanilla, marker="o", linestyle="--", label=r"PSDTW_vanilla")
ax.plot(x, psdtw_parallel_bsf_s, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("Runtime (s)")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
# plt.savefig("../figures/gunpoint-runtime-P3-time.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_parallel_bsf_s, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_parallel_bsf_s, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("Runtime (s)")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
# plt.savefig("../figures/gunpoint-runtime-P3-focus-time.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_vanilla_iter, color=c_vanilla, marker="o", linestyle="-", label=r"PSED_vanilla")
ax.plot(x, psed_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_vanilla_iter, color=c_vanilla, marker="o", linestyle="--", label=r"PSDTW_vanilla")
ax.plot(x, psdtw_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("# Distance Calls")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
# plt.savefig("../figures/gunpoint-runtime-P3-distance-call.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("# Distance Calls")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
# plt.savefig("../figures/gunpoint-runtime-P3-focus-distance-call.pdf", format="pdf", bbox_inches="tight")

plt.show()

# %% [markdown]
# # P = 4

# %%
# psed_vanilla
psed_vanilla_s = [15.052325010299683, 177.512925863266, 611.9721722602844, 1569.3812696933746] # *!
psed_vanilla_iter = [55807524, 633615865, 2219763530, 5391012077] # *!

# psed_parallel_bsf
psed_parallel_bsf_s = [0.935809850692749, 2.332282066345215, 4.934388637542725, 8.855860710144043]
psed_parallel_bsf_iter = [6110633, 56588844, 184247964, 414364678]

# psed_parallel_bsf_lb
psed_parallel_bsf_lb_s = [1.6533668041229248, 3.8153388500213623, 7.100330591201782, 13.029767274856567]
psed_parallel_bsf_lb_iter = [5469443, 47174992, 149388291, 330213309]

# psdtw_vanilla
psdtw_vanilla_s = [195.6351683139801, 2608.994746685028, 10508.590821027756, 26636.67839407921] # *!
psdtw_vanilla_iter = [57731720, 622474506, 2113327505, 5080772940] # *!

# psdtw_parallel_bsf
psdtw_parallel_bsf_s = [7.3900604248046875, 37.53307342529297, 86.27204251289368, 178.06434726715088]
psdtw_parallel_bsf_iter = [9924331, 78275804, 225163621, 514254175]

# psdtw_parallel_bsf_lb
psdtw_parallel_bsf_lb_s = [6.797137022018433, 31.967873573303223, 75.74573850631714, 144.69158339500427]
psdtw_parallel_bsf_lb_iter = [8740547, 63616974, 175550615, 386718825]

# Speedup: 1.09x	1.17x	1.14x	1.23x

# %%
for i in range(4):
    time_for_lb_psed = psed_parallel_bsf_lb_s[i] - (psed_parallel_bsf_s[i] / psed_parallel_bsf_iter[i]) * psed_parallel_bsf_lb_iter[i]
    print(
        f"Time for LB (PSED): {time_for_lb_psed:.3f} "
        f"Time proportion for LB (PSED): {time_for_lb_psed/psed_parallel_bsf_lb_s[i]:.3f} "
    )
print("\n")
for i in range(4):
    time_for_lb_psdtw = psdtw_parallel_bsf_lb_s[i] - (psdtw_parallel_bsf_s[i] / psdtw_parallel_bsf_iter[i]) * psdtw_parallel_bsf_lb_iter[i]
    print(
        f"Time for LB (PSDTW): {time_for_lb_psdtw:.3f} "
        f"Time proportion for LB (PSDTW): {time_for_lb_psdtw/psdtw_parallel_bsf_lb_s[i]:.3f} "
    )
# Out:
# Time for LB (PSED): 0.816 Time proportion for LB (PSED): 0.493
# Time for LB (PSED): 1.871 Time proportion for LB (PSED): 0.490
# Time for LB (PSED): 3.100 Time proportion for LB (PSED): 0.437
# Time for LB (PSED): 5.972 Time proportion for LB (PSED): 0.458
#
#
# Time for LB (PSDTW): 0.289 Time proportion for LB (PSDTW): 0.042
# Time for LB (PSDTW): 1.464 Time proportion for LB (PSDTW): 0.046
# Time for LB (PSDTW): 8.483 Time proportion for LB (PSDTW): 0.112
# Time for LB (PSDTW): 10.787 Time proportion for LB (PSDTW): 0.075

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_vanilla_s, color=c_vanilla, marker="o", linestyle="-", label=r"PSED_vanilla")
ax.plot(x, psed_parallel_bsf_s, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_vanilla_s, color=c_vanilla, marker="o", linestyle="--", label=r"PSDTW_vanilla")
ax.plot(x, psdtw_parallel_bsf_s, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("Runtime (s)")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
# plt.savefig("../figures/gunpoint-runtime-P4-time.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_parallel_bsf_s, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_parallel_bsf_s, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("Runtime (s)")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
# plt.savefig("../figures/gunpoint-runtime-P4-focus-time.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_vanilla_iter, color=c_vanilla, marker="o", linestyle="-", label=r"PSED_vanilla")
ax.plot(x, psed_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_vanilla_iter, color=c_vanilla, marker="o", linestyle="--", label=r"PSDTW_vanilla")
ax.plot(x, psdtw_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("# Distance Calls")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
# plt.savefig("../figures/gunpoint-runtime-P4-distance-call.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("# Distance Calls")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
# plt.savefig("../figures/gunpoint-runtime-P4-focus-distance-call.pdf", format="pdf", bbox_inches="tight")

plt.show()

# %%
import datetime

print(f"This notebook was last run end-to-end on: {datetime.datetime.now()}\n")
###
###
###
# Out:
# This notebook was last run end-to-end on: 2026-03-15 12:02:09.337971
