# %%
import matplotlib.pyplot as plt

# %%
x = [1.25, 1.50, 1.75, 2.0]

plt.rcParams.update(
    {
        "font.size": 18,
        "axes.labelsize": 20,
        "axes.titlesize": 20,
        "legend.fontsize": 18,
        "xtick.labelsize": 18,
        "ytick.labelsize": 18,
        "figure.figsize": (7, 5),
        "lines.linewidth": 2.2,
    }
)

# %% [markdown]
# # P = 2

# %%
# psed_vanilla
psed_vanilla_s = [12.446736574172974, 118.97893047332764, 412.59264969825745, 745.3477964401245] # *!
psed_vanilla_iter = [30741150, 274334823, 914233016, 1565817691] # *!

# psed_parallel_bsf
psed_parallel_bsf_s = [0.6505200862884521, 1.6363191604614258, 3.406228542327881, 5.293441534042358] # *!
psed_parallel_bsf_iter = [2992455, 20269442, 56320829, 94576636] # *!

# psed_parallel_bsf_lb
psed_parallel_bsf_lb_s = [1.4664733409881592, 3.543118476867676, 7.008204460144043, 10.924464225769043] # *!
psed_parallel_bsf_lb_iter = [2797205, 19110543, 53303752, 90047349] # *!

# psdtw_vanilla
psdtw_vanilla_s = [419.21485781669617, 4559.293148994446, 15245.766177892685, 30396.453424215317] # *!
psdtw_vanilla_iter = [32540659, 274994784, 880764560, 1513184734] # *!

# psdtw_parallel_bsf
psdtw_parallel_bsf_s = [9.947118759155273, 44.81173014640808, 87.74901247024536, 219.69021463394165] # *!
psdtw_parallel_bsf_iter = [4569737, 30152958, 74702661, 128851112] # *!

# psdtw_parallel_bsf_lb
psdtw_parallel_bsf_lb_s = [10.116103410720825, 47.824909687042236, 89.40905022621155, 174.42953372001648] # *!
psdtw_parallel_bsf_lb_iter = [4156260, 28058604, 70500069, 123040644] # *!

# %%
for i in range(4):
    time_for_lb_psed = psed_parallel_bsf_lb_s[i] - (psed_parallel_bsf_s[i] / psed_parallel_bsf_iter[i]) * psed_parallel_bsf_lb_iter[i]
    print(
        f"Time for LB (PSED): {time_for_lb_psed:.3f} "
        f"Time proportion for LB (PSED): {time_for_lb_psed/psed_parallel_bsf_lb_s[i]:.3f} "
    )
print("\n")
for i in range(4):
    time_for_lb_psdtw = psdtw_parallel_bsf_lb_s[i] - (psdtw_parallel_bsf_s[i] / psdtw_parallel_bsf_iter[i]) * psdtw_parallel_bsf_lb_iter[i]
    print(
        f"Time for LB (PSDTW): {time_for_lb_psdtw:.3f} "
        f"Time proportion for LB (PSDTW): {time_for_lb_psdtw/psdtw_parallel_bsf_lb_s[i]:.3f} "
    )
# Out:
# Time for LB (PSED): 0.858 Time proportion for LB (PSED): 0.585
# Time for LB (PSED): 2.000 Time proportion for LB (PSED): 0.565
# Time for LB (PSED): 3.784 Time proportion for LB (PSED): 0.540
# Time for LB (PSED): 5.885 Time proportion for LB (PSED): 0.539
#
#
# Time for LB (PSDTW): 1.069 Time proportion for LB (PSDTW): 0.106
# Time for LB (PSDTW): 6.126 Time proportion for LB (PSDTW): 0.128
# Time for LB (PSDTW): 6.597 Time proportion for LB (PSDTW): 0.074
# Time for LB (PSDTW): -35.354 Time proportion for LB (PSDTW): -0.203

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_vanilla_s, color=c_vanilla, marker="o", linestyle="-", label=r"PSED_vanilla")
ax.plot(x, psed_parallel_bsf_s, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_vanilla_s, color=c_vanilla, marker="o", linestyle="--", label=r"PSDTW_vanilla")
ax.plot(x, psdtw_parallel_bsf_s, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("Runtime (s)")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
plt.savefig("../figures/gunpoint-runtime-P2-time.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_parallel_bsf_s, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_parallel_bsf_s, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("Runtime (s)")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
plt.savefig("../figures/gunpoint-runtime-P2-focus-time.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_vanilla_iter, color=c_vanilla, marker="o", linestyle="-", label=r"PSED_vanilla")
ax.plot(x, psed_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_vanilla_iter, color=c_vanilla, marker="o", linestyle="--", label=r"PSDTW_vanilla")
ax.plot(x, psdtw_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("# Distance Calls")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
plt.savefig("../figures/gunpoint-runtime-P2-distance-call.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("# Distance Calls")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
plt.savefig("../figures/gunpoint-runtime-P2-focus-distance-call.pdf", format="pdf", bbox_inches="tight")

plt.show()

# %% [markdown]
# # P = 3

# %%
# psed_vanilla
psed_vanilla_s = [18.394218921661377, 215.26686477661133, 700.9349184036255, 1529.5894598960876] # *!
psed_vanilla_iter = [60658171, 659109745, 2119408092, 4200540991] # *!

# psed_parallel_bsf
psed_parallel_bsf_s = [0.8425712585449219, 2.4282193183898926, 4.620831727981567, 7.07088828086853] # *!
psed_parallel_bsf_iter = [5267318, 51075577, 143359236, 257631639] # *!

# psed_parallel_bsf_lb
psed_parallel_bsf_lb_s = [1.417912483215332, 4.12555193901062, 7.568490982055664, 11.832161903381348] # *!
psed_parallel_bsf_lb_iter = [4657765, 46548642, 131980106, 238938531] # *!

# psdtw_vanilla
psdtw_vanilla_s = [341.6239402294159, 5044.003716945648, 16391.769976854324, 37835.05887246132] # *!
psdtw_vanilla_iter = [63268968, 664255610, 2056565223, 4054178881] # *!

# psdtw_parallel_bsf
psdtw_parallel_bsf_s = [8.160111665725708, 50.69209432601929, 106.95612478256226, 206.44076490402222] # *!
psdtw_parallel_bsf_iter = [8912764, 78233980, 193658179, 370697041] # *!

# psdtw_parallel_bsf_lb
psdtw_parallel_bsf_lb_s = [8.079408407211304, 50.83686137199402, 103.06196808815002, 197.47336554527283] # *!
psdtw_parallel_bsf_lb_iter = [7954169, 71966267, 180478062, 348141022] # *!

# %%
for i in range(4):
    time_for_lb_psed = psed_parallel_bsf_lb_s[i] - (psed_parallel_bsf_s[i] / psed_parallel_bsf_iter[i]) * psed_parallel_bsf_lb_iter[i]
    print(
        f"Time for LB (PSED): {time_for_lb_psed:.3f} "
        f"Time proportion for LB (PSED): {time_for_lb_psed/psed_parallel_bsf_lb_s[i]:.3f} "
    )
print("\n")
for i in range(4):
    time_for_lb_psdtw = psdtw_parallel_bsf_lb_s[i] - (psdtw_parallel_bsf_s[i] / psdtw_parallel_bsf_iter[i]) * psdtw_parallel_bsf_lb_iter[i]
    print(
        f"Time for LB (PSDTW): {time_for_lb_psdtw:.3f} "
        f"Time proportion for LB (PSDTW): {time_for_lb_psdtw/psdtw_parallel_bsf_lb_s[i]:.3f} "
    )
# Out:
# Time for LB (PSED): 0.673 Time proportion for LB (PSED): 0.475
# Time for LB (PSED): 1.913 Time proportion for LB (PSED): 0.464
# Time for LB (PSED): 3.314 Time proportion for LB (PSED): 0.438
# Time for LB (PSED): 5.274 Time proportion for LB (PSED): 0.446
#
#
# Time for LB (PSDTW): 0.797 Time proportion for LB (PSDTW): 0.099
# Time for LB (PSDTW): 4.206 Time proportion for LB (PSDTW): 0.083
# Time for LB (PSDTW): 3.385 Time proportion for LB (PSDTW): 0.033
# Time for LB (PSDTW): 3.594 Time proportion for LB (PSDTW): 0.018

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_vanilla_s, color=c_vanilla, marker="o", linestyle="-", label=r"PSED_vanilla")
ax.plot(x, psed_parallel_bsf_s, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_vanilla_s, color=c_vanilla, marker="o", linestyle="--", label=r"PSDTW_vanilla")
ax.plot(x, psdtw_parallel_bsf_s, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("Runtime (s)")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
plt.savefig("../figures/gunpoint-runtime-P3-time.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_parallel_bsf_s, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_parallel_bsf_s, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("Runtime (s)")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
plt.savefig("../figures/gunpoint-runtime-P3-focus-time.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_vanilla_iter, color=c_vanilla, marker="o", linestyle="-", label=r"PSED_vanilla")
ax.plot(x, psed_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_vanilla_iter, color=c_vanilla, marker="o", linestyle="--", label=r"PSDTW_vanilla")
ax.plot(x, psdtw_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("# Distance Calls")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
plt.savefig("../figures/gunpoint-runtime-P3-distance-call.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("# Distance Calls")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
plt.savefig("../figures/gunpoint-runtime-P3-focus-distance-call.pdf", format="pdf", bbox_inches="tight")

plt.show()

# %% [markdown]
# # P = 4

# %%
# psed_vanilla
psed_vanilla_s = [15.052325010299683, 177.512925863266, 611.9721722602844, 1569.3812696933746] # *!
psed_vanilla_iter = [55807524, 633615865, 2219763530, 5391012077] # *!

# psed_parallel_bsf
psed_parallel_bsf_s = [0.8776233196258545, 2.4680612087249756, 5.671298980712891, 6.663231372833252]
psed_parallel_bsf_iter = [4254284, 39455107, 125826352, 275505504]

# psed_parallel_bsf_lb
psed_parallel_bsf_lb_s = [1.3760368824005127, 3.1169581413269043, 7.227363348007202, 10.284342527389526]
psed_parallel_bsf_lb_iter = [3681143, 34607337, 111990633, 251633284]

# psdtw_vanilla
psdtw_vanilla_s = [195.6351683139801, 2608.994746685028, 10508.590821027756, 26636.67839407921] # *!
psdtw_vanilla_iter = [57731720, 622474506, 2113327505, 5080772940] # *!

# psdtw_parallel_bsf
psdtw_parallel_bsf_s = [5.664880752563477, 33.99344229698181, 73.87368679046631, 140.59199571609497]
psdtw_parallel_bsf_iter = [8000962, 62192735, 165392918, 388281917]

# psdtw_parallel_bsf_lb
psdtw_parallel_bsf_lb_s = [5.8382744789123535, 32.81467580795288, 60.3810875415802, 130.05123233795166]
psdtw_parallel_bsf_lb_iter = [7174046, 55683047, 150059956, 358248378]

# %%
for i in range(4):
    time_for_lb_psed = psed_parallel_bsf_lb_s[i] - (psed_parallel_bsf_s[i] / psed_parallel_bsf_iter[i]) * psed_parallel_bsf_lb_iter[i]
    print(
        f"Time for LB (PSED): {time_for_lb_psed:.3f} "
        f"Time proportion for LB (PSED): {time_for_lb_psed/psed_parallel_bsf_lb_s[i]:.3f} "
    )
print("\n")
for i in range(4):
    time_for_lb_psdtw = psdtw_parallel_bsf_lb_s[i] - (psdtw_parallel_bsf_s[i] / psdtw_parallel_bsf_iter[i]) * psdtw_parallel_bsf_lb_iter[i]
    print(
        f"Time for LB (PSDTW): {time_for_lb_psdtw:.3f} "
        f"Time proportion for LB (PSDTW): {time_for_lb_psdtw/psdtw_parallel_bsf_lb_s[i]:.3f} "
    )
# Out:
# Time for LB (PSED): 0.617 Time proportion for LB (PSED): 0.448
# Time for LB (PSED): 0.952 Time proportion for LB (PSED): 0.305
# Time for LB (PSED): 2.180 Time proportion for LB (PSED): 0.302
# Time for LB (PSED): 4.198 Time proportion for LB (PSED): 0.408
#
#
# Time for LB (PSDTW): 0.759 Time proportion for LB (PSDTW): 0.130
# Time for LB (PSDTW): 2.379 Time proportion for LB (PSDTW): 0.073
# Time for LB (PSDTW): -6.644 Time proportion for LB (PSDTW): -0.110
# Time for LB (PSDTW): 0.334 Time proportion for LB (PSDTW): 0.003

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_vanilla_s, color=c_vanilla, marker="o", linestyle="-", label=r"PSED_vanilla")
ax.plot(x, psed_parallel_bsf_s, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_vanilla_s, color=c_vanilla, marker="o", linestyle="--", label=r"PSDTW_vanilla")
ax.plot(x, psdtw_parallel_bsf_s, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("Runtime (s)")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
plt.savefig("../figures/gunpoint-runtime-P4-time.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_parallel_bsf_s, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_parallel_bsf_s, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_s, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("Runtime (s)")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
plt.savefig("../figures/gunpoint-runtime-P4-focus-time.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_vanilla_iter, color=c_vanilla, marker="o", linestyle="-", label=r"PSED_vanilla")
ax.plot(x, psed_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_vanilla_iter, color=c_vanilla, marker="o", linestyle="--", label=r"PSDTW_vanilla")
ax.plot(x, psdtw_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("# Distance Calls")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
plt.savefig("../figures/gunpoint-runtime-P4-distance-call.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots()

# === Color & Style Definitions ===
# Colors distinguish the specific implementation/variant
c_vanilla = "tab:blue"
c_parallel = "tab:red"
c_parallel_lb = "tab:green"

# === Plotting PSED (Solid Lines) ===
ax.plot(x, psed_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="-", label=r"PSED_parallel_bsf")
ax.plot(x, psed_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="-", label=r"PSED_parallel_bsf_lb")

# === Plotting PSDTW (Dashed Lines) ===
ax.plot(x, psdtw_parallel_bsf_iter, color=c_parallel, marker="^", linestyle="--", label=r"PSDTW_parallel_bsf")
ax.plot(x, psdtw_parallel_bsf_lb_iter, color=c_parallel_lb, marker="s", linestyle="--", label=r"PSDTW_parallel_bsf_lb")

ax.set_xlabel("Scaling Factor $l$")
ax.set_ylabel("# Distance Calls")

# ax.set_yscale("log")

ax.set_xticks([1.25, 1.50, 1.75, 2.0])

ax.grid(True, which="both", ls="--", lw=0.5, alpha=0.6)

# === Legend ===
# Placed outside to prevent covering data if the plot is crowded
ax.legend(loc="upper left")

plt.tight_layout()
plt.savefig("../figures/gunpoint-runtime-P4-focus-distance-call.pdf", format="pdf", bbox_inches="tight")

plt.show()

# %%
import datetime

print(f"This notebook was last run end-to-end on: {datetime.datetime.now()}\n")
###
###
###
# Out:
# This notebook was last run end-to-end on: 2026-04-02 11:47:37.484406
